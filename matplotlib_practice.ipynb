# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.3.4'

# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %% [markdown]
# ## Line graph

# %%
# Create the plot
plt.plot(x_axis , y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis , y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
fig = plt.figure()

# %%
# Create the plot.
plt.plot(x_axis, y_axis)
plt.xlabel("Months")
plt.ylabel("Fares ($)")
plt.title("Fares Analysis")
plt.show()

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# Object oriented interface (ax)
#Change the line color to green.
#Change the marker to a diamond.
#Change the line width to 2 points.
#Add a legend for the city of Boston.
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis, marker = "d", color = "green",linewidth =2, label='Boston')
#Add a title and axes labels.
ax.set_title("PyBer fare by month")
ax.set_xlabel("Date")
ax.set_ylabel("Fare ($)")
#Add a y-axis limit.
ax.set_ylim(0, 45)
#Add grid lines.
ax.grid()
plt.show()

# %% [markdown]
# ## Bar graph

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Create the plot.
plt.barh(x_axis, y_axis, color="magenta",label="Boston")
plt.gca().invert_yaxis()
plt.legend()
plt.xlabel("Fare ($)")
plt.ylabel("Date")
plt.title("PyBer Fare by Month")
# Out:
# Text(0.5, 1.0, 'PyBer Fare by Month')

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, color = "k",label = "New York City")
ax.set_xlabel("Date")
ax.set_ylabel("Fares")
ax.legend()

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Change the bar color to cyan.
#Add a legend for the city of Chicago.
#Add a title and axes labels.
#Switch the axis so that the Fare($) data is on the x-axis.
#Invert the y-axis data.
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color = "cyan", label = "Chicago")
ax.set_title("PyBer Fare by Month")
ax.set_xlabel("Fares")
ax.set_ylabel("Date")
ax.legend()
ax.invert_yaxis()

# %% [markdown]
# ## Scatter Plot and Bubble chart

# %% [markdown]
# ### Scatter Plot

# %%
plt.plot(x_axis, y_axis, 'o')

# %%
plt.scatter(x_axis, y_axis)

# %%
#Change the color of the markers to red.
#Switch the axis so that the Fare($) data is on the x-axis.
plt.scatter(y_axis,x_axis, c= "red",label = "Chicago")
#Add a legend for the city of Chicago.
plt.legend()
#Add a title and axes labels.
plt.xlabel("Fares )$")
plt.ylabel("Date")
plt.title("PyBer Fare by Month")
#Add a limit for the x-axis data.
plt.xlim(0,45)
#Invert the y-axis so that January is at the top.
plt.gca().invert_yaxis()

# %% [markdown]
# ### Bubble chart

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
#Change the color of the markers to sky blue.
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, color ="blue",alpha=0.2, linewidth = 2, edgecolors ="Black", label = "Boston", s=[i * 5 for i in y_axis])
#Change the size of the markers to 5 times each data point.

#Make the color 20% transparent.

#Add a black edge color to the circles.

#Make the linewidth of the circles 2 points.

#Add a legend for the city of Boston.
ax.legend()
#Add a title.
ax.set_title("PyBer Fare by Month")
ax.set_xlabel("Fares ($)")
ax.set_ylabel("Date")
#Switch the axis so that the Fare($) data is on the x-axis.

#Add a limit for the x-axis data.
#ax.set_xlim(0,45)
#Invert the y-axis so that January is at the top.
ax.invert_yaxis()

# %% [markdown]
# ### Pie Chart

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
#Adding %
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd4ba664e20>,
#   <matplotlib.patches.Wedge at 0x7fd4ba673550>,
#   <matplotlib.patches.Wedge at 0x7fd4ba673be0>,
#   <matplotlib.patches.Wedge at 0x7fd4ba6812b0>,
#   <matplotlib.patches.Wedge at 0x7fd4ba681940>,
#   <matplotlib.patches.Wedge at 0x7fd4ba681fd0>,
#   <matplotlib.patches.Wedge at 0x7fd4ba68f6a0>,
#   <matplotlib.patches.Wedge at 0x7fd4ba68fd30>,
#   <matplotlib.patches.Wedge at 0x7fd4ba69e400>,
#   <matplotlib.patches.Wedge at 0x7fd4ba69ea90>,
#   <matplotlib.patches.Wedge at 0x7fd4ba5d9880>,
#   <matplotlib.patches.Wedge at 0x7fd4ba6ac7c0>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.5907474957304654, 1.1580230551626267, 'Mar'),
#   Text(-0.32930826971286276, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452757, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.23338752507546193, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.460981299980763, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.36353692044951713, 0.7126295724077703, '13.0%'),
#   Text(-0.17962269257065241, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883321, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.1273022864047974, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis, autopct="%.1f%%",explode = explode_values)
explode_values = (0,0,0,0,0,0,0.2,0,0,0,0,0,)
plt.show()

# %%
#Add a percentage to one decimal place to each wedge of the pie.
#Increase the figure size to 8x8.
#Explode the two highest percentage months.
#Add a shadow.
#Add a start angle so that January is at the top.
#Reverse the order so that the month order is in a clockwise direction.
#Add new colors of your own choosing or use the colors from the previous pie chart.

fig, ax = plt.subplots(figsize=(8,8))
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0) 
ax.pie(y_axis,
    explode=explode_values,
    colors=colors,
    shadow = True,
    startangle = 90,   
    labels=x_axis,
    counterclock = False,
    autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd4ba77f3a0>,
#   <matplotlib.patches.Wedge at 0x7fd4b3383370>,
#   <matplotlib.patches.Wedge at 0x7fd4b3383400>,
#   <matplotlib.patches.Wedge at 0x7fd4bb0b91f0>,
#   <matplotlib.patches.Wedge at 0x7fd4bb0b9bb0>,
#   <matplotlib.patches.Wedge at 0x7fd4ba9e23a0>,
#   <matplotlib.patches.Wedge at 0x7fd4ba9e2bb0>,
#   <matplotlib.patches.Wedge at 0x7fd4b337a2e0>,
#   <matplotlib.patches.Wedge at 0x7fd4ba51bb80>,
#   <matplotlib.patches.Wedge at 0x7fd4ba51b400>,
#   <matplotlib.patches.Wedge at 0x7fd4b94ac130>,
#   <matplotlib.patches.Wedge at 0x7fd4b9e5b430>],
#  [Text(0.11437852557419122, 1.0940372721655667, 'Jan'),
#   Text(0.47840516097536223, 0.9905193092273052, 'Feb'),
#   Text(0.9798656620606843, 0.4998632656180859, 'Mar'),
#   Text(1.0495504101751, -0.3293082697128627, 'April'),
#   Text(0.5864693241605263, -0.9306200792045569, 'May'),
#   Text(-0.06046434452452764, -1.0983369533258995, 'June'),
#   Text(-0.9249785389235748, -0.9134630274569459, 'July'),
#   Text(-1.0749559354406817, -0.23338752507546184, 'Aug'),
#   Text(-1.099797660024518, 0.021097559209412815, 'Sept'),
#   Text(-0.9987473359504124, 0.46098129998076304, 'Oct'),
#   Text(-0.6507384104340302, 0.8868706338501641, 'Nov'),
#   Text(-0.2280764638483437, 1.0760953148482877, 'Dec')],
#  [Text(0.062388286676831564, 0.5967476029993999, '3.3%'),
#   Text(0.26094826962292483, 0.5402832595785301, '7.7%'),
#   Text(0.5344721793058277, 0.27265269033713774, '13.0%'),
#   Text(0.5724820419136909, -0.17962269257065236, '11.7%'),
#   Text(0.3198923586330143, -0.5076109522933946, '10.7%'),
#   Text(-0.032980551558833254, -0.5990928836323088, '8.9%'),
#   Text(-0.5692175624145076, -0.5621310938196589, '14.5%'),
#   Text(-0.5863396011494626, -0.12730228640479735, '3.5%'),
#   Text(-0.5998896327406462, 0.011507759568770625, '3.9%'),
#   Text(-0.5447712741547703, 0.25144434544405253, '9.2%'),
#   Text(-0.35494822387310737, 0.4837476184637258, '6.9%'),
#   Text(-0.12440534391727837, 0.5869610808263387, '6.6%')])
